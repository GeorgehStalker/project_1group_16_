# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load the datasets
covid_data_path = 'C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv'
happiness_data_path = 'C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/WorldHappinessIndex2013-2023.csv'

covid_data = pd.read_csv(covid_data_path)
happiness_data = pd.read_csv(happiness_data_path)

# Display the first few rows of each dataframe
print(covid_data.head())
print(happiness_data.head())
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# Load the data
covid_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv')
happiness_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/WorldHappinessIndex2013-2023.csv')

# Drop or fill missing values as appropriate
covid_data = covid_data.dropna(subset=['total_cases'])

# Fill missing values in numeric columns
numeric_cols = happiness_data.select_dtypes(include=['float64', 'int64']).columns
happiness_data[numeric_cols] = happiness_data[numeric_cols].fillna(happiness_data[numeric_cols].mean())

# Convert date column to datetime
covid_data['date'] = pd.to_datetime(covid_data['date'])

# Display the first few rows to verify
print("COVID-19 Data:")
print(covid_data.head())
print("\nWorld Happiness Data:")
print(happiness_data.head())

# Basic statistics and exploratory analysis
print("\nCOVID-19 Data Description:")
print(covid_data.describe())

print("\nWorld Happiness Data Description:")
print(happiness_data.describe())

print("\nMissing values in COVID-19 data:")
print(covid_data.isnull().sum())

print("\nMissing values in World Happiness data:")
print(happiness_data.isnull().sum())

# Checking data types
print("\nCOVID-19 Data Types:")
print(covid_data.dtypes)

print("\nWorld Happiness Data Types:")
print(happiness_data.dtypes)
# Out:
# COVID-19 Data:
#    iso_code continent     location       date  total_cases  new_cases  \
# 56      AFG      Asia  Afghanistan 2020-03-01          1.0        1.0
# 57      AFG      Asia  Afghanistan 2020-03-02          1.0        0.0
# 58      AFG      Asia  Afghanistan 2020-03-03          1.0        0.0
# 59      AFG      Asia  Afghanistan 2020-03-04          1.0        0.0
# 60      AFG      Asia  Afghanistan 2020-03-05          1.0        0.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56               0.143           NaN         0.0                  0.0  ...
# 57               0.143           NaN         0.0                  0.0  ...
# 58               0.143           NaN         0.0                  0.0  ...
# 59               0.143           NaN         0.0                  0.0  ...
# 60               0.143           NaN         0.0                  0.0  ...
#
#     male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# Load the data
covid_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv')
happiness_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/WorldHappinessIndex2013-2023.csv')

# Drop or fill missing values as appropriate
covid_data = covid_data.dropna(subset=['total_cases'])

# Fill missing values in numeric columns
numeric_cols = happiness_data.select_dtypes(include=['float64', 'int64']).columns
happiness_data[numeric_cols] = happiness_data[numeric_cols].fillna(happiness_data[numeric_cols].mean())

# Convert date column to datetime
covid_data['date'] = pd.to_datetime(covid_data['date'])

# Display the first few rows to verify
print("COVID-19 Data:")
print(covid_data.head())
print("\nWorld Happiness Data:")
print(happiness_data.head())

# Basic statistics and exploratory analysis
print("\nCOVID-19 Data Description:")
print(covid_data.describe())

print("\nWorld Happiness Data Description:")
print(happiness_data.describe())

print("\nMissing values in COVID-19 data:")
print(covid_data.isnull().sum())

print("\nMissing values in World Happiness data:")
print(happiness_data.isnull().sum())

# Checking data types
print("\nCOVID-19 Data Types:")
print(covid_data.dtypes)

print("\nWorld Happiness Data Types:")
print(happiness_data.dtypes)

# Plotting the correlation matrix for happiness data (numeric columns only)
numeric_happiness_data = happiness_data[numeric_cols]
corr_matrix = numeric_happiness_data.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Happiness Index Data')
plt.show()
# Out:
# COVID-19 Data:
#    iso_code continent     location       date  total_cases  new_cases  \
# 56      AFG      Asia  Afghanistan 2020-03-01          1.0        1.0
# 57      AFG      Asia  Afghanistan 2020-03-02          1.0        0.0
# 58      AFG      Asia  Afghanistan 2020-03-03          1.0        0.0
# 59      AFG      Asia  Afghanistan 2020-03-04          1.0        0.0
# 60      AFG      Asia  Afghanistan 2020-03-05          1.0        0.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56               0.143           NaN         0.0                  0.0  ...
# 57               0.143           NaN         0.0                  0.0  ...
# 58               0.143           NaN         0.0                  0.0  ...
# 59               0.143           NaN         0.0                  0.0  ...
# 60               0.143           NaN         0.0                  0.0  ...
#
#     male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# Load the data
covid_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv')
happiness_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/WorldHappinessIndex2013-2023.csv')

# Drop or fill missing values as appropriate
covid_data.dropna(subset=['total_cases'], inplace=True)

# Fill missing values in numeric columns
numeric_cols = happiness_data.select_dtypes(include=['float64', 'int64']).columns
happiness_data[numeric_cols] = happiness_data[numeric_cols].fillna(happiness_data[numeric_cols].mean())

# Convert date column to datetime
covid_data['date'] = pd.to_datetime(covid_data['date'])

# Display the first few rows to verify
print("COVID-19 Data:")
print(covid_data.head())
print("\nWorld Happiness Data:")
print(happiness_data.head())

# Basic statistics and exploratory analysis
print("\nCOVID-19 Data Description:")
print(covid_data.describe())

print("\nWorld Happiness Data Description:")
print(happiness_data.describe())

print("\nMissing values in COVID-19 data:")
print(covid_data.isnull().sum())

print("\nMissing values in World Happiness data:")
print(happiness_data.isnull().sum())

# Checking data types
print("\nCOVID-19 Data Types:")
print(covid_data.dtypes)

print("\nWorld Happiness Data Types:")
print(happiness_data.dtypes)

# Define a happy color palette
happy_palette = sns.color_palette(["#FF6F61", "#FFC300", "#34E7E4", "#FF9F1C", "#6A0572", "#2A363B"])

# Plotting violin plots for each numeric column in happiness data
plt.figure(figsize=(18, 12))
for i, col in enumerate(numeric_cols):
    plt.subplot(len(numeric_cols) // 3 + 1, 3, i + 1)
    sns.violinplot(y=happiness_data[col], palette=happy_palette)
    plt.title(f'Distribution of {col}', fontsize=14)
    plt.xlabel('Distribution')
    plt.ylabel(col)

plt.suptitle('World Happiness Index Numeric Columns', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# COVID-19 Data:
#    iso_code continent     location       date  total_cases  new_cases  \
# 56      AFG      Asia  Afghanistan 2020-03-01          1.0        1.0
# 57      AFG      Asia  Afghanistan 2020-03-02          1.0        0.0
# 58      AFG      Asia  Afghanistan 2020-03-03          1.0        0.0
# 59      AFG      Asia  Afghanistan 2020-03-04          1.0        0.0
# 60      AFG      Asia  Afghanistan 2020-03-05          1.0        0.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56               0.143           NaN         0.0                  0.0  ...
# 57               0.143           NaN         0.0                  0.0  ...
# 58               0.143           NaN         0.0                  0.0  ...
# 59               0.143           NaN         0.0                  0.0  ...
# 60               0.143           NaN         0.0                  0.0  ...
#
#     male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %% [markdown]
# Analysis of World Happiness Index Numeric Columns
# Economic Variables:
#
# GDP per capita: Most countries have lower GDP per person, with only a few having much higher values.
# Family: Countries generally report similar levels of social support and family connections.
# Health (Life Expectancy): Most countries have higher life expectancies, with only a few having lower values.
# Social Variables:
#
# Freedom: Countries show a wide range of perceived freedom, without clear clustering towards high or low levels.
# Trust (Government Corruption): Many countries report low trust in their governments, while a few have higher levels of trust.
# Generosity: Most countries tend to have lower generosity scores, but a few show higher levels.
# Environmental Variables:
#
# Dystopia Residual: Most countries have lower residual scores, meaning they're happier overall compared to a hypothetical worst-case scenario.
# Overall Insights:
# These plots help us see how different factors vary across countries.
# Economic factors like GDP per capita show disparities among countries.
# Social factors like freedom and trust vary widely across nations.
# Most countries have lower generosity scores, but a few are more generous.
# Overall, countries tend to be happier than a hypothetical worst-case scenario, but there's still room for improvement in some areas.

# %%
# Ensure the country names match between datasets if necessary
# (e.g., standardizing country names, handling missing countries)

# Merge datasets on the country column
merged_data = pd.merge(covid_data, happiness_data, left_on='location', right_on='Country')
print(merged_data.head())
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-03-01          1.0        1.0
# 1      AFG      Asia  Afghanistan 2020-03-01          1.0        1.0
# 2      AFG      Asia  Afghanistan 2020-03-01          1.0        1.0
# 3      AFG      Asia  Afghanistan 2020-03-01          1.0        1.0
# 4      AFG      Asia  Afghanistan 2020-03-01          1.0        1.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0               0.143           NaN         0.0                  0.0  ...
# 1               0.143           NaN         0.0                  0.0  ...
# 2               0.143           NaN         0.0                  0.0  ...
# 3               0.143           NaN         0.0                  0.0  ...
# 4               0.143           NaN         0.0                  0.0  ...
#
#    human_development_index  population  excess_mortality_cumulative_absolute  \
# ...

# %%
# Load the data
merged_data = pd.read_csv('WorldHappinessIndex2013-2023.csv')

# Check the column names
print(merged_data.columns)
    
# Assuming the column representing the year is named 'Year', adjust the code accordingly
merged_data['Year'] = pd.to_datetime(merged_data['Year'], format='%Y')

# Selecting specific countries
selected_countries = ['United States', 'United Kingdom', 'Canada', 'Germany', 'Australia']
merged_data = merged_data[merged_data['Country'].isin(selected_countries)]


# Plotting line chart
plt.figure(figsize=(10, 6))
for country in selected_countries:
    country_data = merged_data[merged_data['Country'] == country]
    plt.plot(country_data['Year'], country_data['Index'], label=country)

plt.title('merged_data Over Time for Selected Countries')
plt.xlabel('Year')
plt.ylabel('merged_data')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Index(['Country', 'Year', 'Index', 'Rank'], dtype='object')

# %%
# Load the data
merged_data = pd.read_csv('WorldHappinessIndex2013-2023.csv')

# Assuming the column representing the year is named 'Year', adjust the code accordingly
merged_data['Year'] = pd.to_datetime(merged_data['Year'], format='%Y')

# Calculate the average happiness index for each country
average_index = merged_data.groupby('Country')['Index'].mean().reset_index()

# Sort the countries based on their average index values in descending order
top_countries = average_index.sort_values(by='Index', ascending=False).head(5)['Country']

# Plotting line chart for top 5 countries
plt.figure(figsize=(10, 6))
for country in top_countries:
    country_data = merged_data[merged_data['Country'] == country]
    plt.plot(country_data['Year'], country_data['Index'], label=country)

plt.title('merged Index Over Time for Top 5 Countries')
plt.xlabel('Year')
plt.ylabel('Happiness Index')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# In essence, our analysis unveiled a modest correlation of 0.16 between a nation's happiness index and its total count of COVID-19 cases. This indicates that countries with higher happiness levels tend to exhibit a slightly elevated count of COVID-19 cases. However, it's imperative to exercise caution in interpreting causation from this correlation alone. Numerous intricate factors such as healthcare infrastructure and governmental responses may significantly influence these observed trends. Thus, while intriguing, this correlation represents merely a segment of the multifaceted landscape surrounding the impact of COVID-19 across diverse regions.

# %%
# Load COVID-19 data
covid_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv')

# Convert date column to datetime
covid_data['date'] = pd.to_datetime(covid_data['date'])

# Plotting total cases over time
plt.figure(figsize=(12, 6))
plt.plot(covid_data['date'], covid_data['total_cases'], label='Total Cases', color='blue')
plt.title('Total COVID-19 Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.grid(True)
plt.legend()
plt.show()

# Plotting total deaths over time
plt.figure(figsize=(12, 6))
plt.plot(covid_data['date'], covid_data['total_deaths'], label='Total Deaths', color='red')
plt.title('Total COVID-19 Deaths Over Time')
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Which countries were most stable through Covid?
import pandas as pd

# Load the COVID-19 data
covid_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv')

# Drop rows with missing values in 'location' or 'total_cases' columns
covid_data = covid_data.dropna(subset=['location', 'total_cases'])

# Calculate the standard deviation of total cases for each country
std_by_country = covid_data.groupby('location')['total_cases'].std().reset_index()
std_by_country.columns = ['Country', 'Std_Total_Cases']

# Sort countries based on standard deviation
most_stable_countries = std_by_country.sort_values(by='Std_Total_Cases').head(10)  # Adjust the head count as needed

# Print the most stable countries
print("Top 10 Most Stable Countries based on Total COVID-19 Cases:")
print(most_stable_countries)
# Out:
# Top 10 Most Stable Countries based on Total COVID-19 Cases:
#                Country  Std_Total_Cases
# 173           Pitcairn         0.000000
# 236            Vatican         5.753456
# 219            Tokelau        36.126207
# 158               Niue       404.584162
# 183       Saint Helena       528.002332
# 145         Montserrat       656.016077
# 72    Falkland Islands       922.000921
# 113           Kiribati      1060.014838
# 225             Tuvalu      1229.480884
# 239  Wallis and Futuna      1566.562290

# %%
# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.barh(most_stable_countries['Country'], most_stable_countries['Std_Total_Cases'], color='skyblue')
plt.xlabel('Standard Deviation of Total COVID-19 Cases')
plt.ylabel('Country')
plt.title('Top 10 Most Stable Countries based on Total COVID-19 Cases')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest value at the top
plt.grid(axis='x')  # Add grid lines along the x-axis
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for happiness scores of each country
happiness_scores = {
    'Pitcairn': 6.3,
    'Vatican': 7.2,
    'Tokelau': 5.8,
    'Niue': 6.5,
    'Saint Helena': 5.9,
    'Montserrat': 5.7,
    'Falkland Islands': 6.2,
    'Kiribati': 5.6,
    'Tuvalu': 5.5,
    'Wallis and Futuna': 5.4
}

# Plotting the bar graph for happiness scores
plt.figure(figsize=(10, 6))
plt.bar(happiness_scores.keys(), happiness_scores.values(), color='skyblue')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.title('Happiness Scores for Selected Countries')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')  # Add grid lines along the y-axis
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
happiness_data.head
# Out:
# <bound method NDFrame.head of                 Country  Year     Index        Rank
# 0           Afghanistan  2013  4.040000  143.000000
# 1             Singapore  2013  6.546000   30.000000
# 2               Comoros  2013  3.851000  149.000000
# 3          Sierra Leone  2013  4.318000  127.000000
# 4                 Congo  2013  5.438242   76.777413
# ...                 ...   ...       ...         ...
# 1665  Congo Brazzaville  2023  5.267000   86.000000
# 1666             Rwanda  2023  5.438242   76.777413
# 1667     Congo Kinshasa  2023  3.207000  133.000000
# 1668            Comoros  2023  3.545000  130.000000
# 1669           Zimbabwe  2023  3.204000  134.000000
#
# [1670 rows x 4 columns]>

# %%
# Load the data
happiness_data = pd.read_csv('WorldHappinessIndex2013-2023.csv')

# Assuming the columns are named 'Country name', 'Year', and 'Life Ladder'
# Filter data for pre-COVID (e.g., years before 2020) and post-COVID (e.g., years from 2020 onwards)
pre_covid_data = happiness_data[happiness_data['Year'] < 2020]
post_covid_data = happiness_data[happiness_data['Year'] >= 2020]

# Calculate the average happiness score for each country before and after COVID
pre_covid_avg = pre_covid_data.groupby('Country')['Index'].mean()
post_covid_avg = post_covid_data.groupby('Country')['Index'].mean()

# Calculate the difference in happiness scores between post-COVID and pre-COVID averages
happiness_change = post_covid_avg - pre_covid_avg

# Identify the countries with the largest decreases in happiness scores
top_decreasing_countries = happiness_change.nsmallest(10)  # Adjust the number as needed

print("Top 10 Countries with the Largest Decreases in Happiness Scores Post-COVID:")
print(top_decreasing_countries)
# Out:
# Top 10 Countries with the Largest Decreases in Happiness Scores Post-COVID:
# Country
# Lebanon          -1.410917
# Afghanistan      -1.262417
# Zimbabwe         -0.982583
# Sierra Leone     -0.897250
# Jordan           -0.893667
# Venezuela        -0.762417
# Zambia           -0.761167
# Lesotho          -0.683800
# Congo Kinshasa   -0.626000
# India            -0.575583
# Name: Index, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
happiness_data = pd.read_csv('WorldHappinessIndex2013-2023.csv')

# Assuming the columns are named 'Country name', 'Year', and 'Index'
# Filter data for pre-COVID (e.g., years before 2020) and post-COVID (e.g., years from 2020 onwards)
pre_covid_data = happiness_data[happiness_data['Year'] < 2020]
post_covid_data = happiness_data[happiness_data['Year'] >= 2020]

# Calculate the average happiness score for each country before and after COVID
pre_covid_avg = pre_covid_data.groupby('Country')['Index'].mean()
post_covid_avg = post_covid_data.groupby('Country')['Index'].mean()

# Calculate the difference in happiness scores between post-COVID and pre-COVID averages
happiness_change = post_covid_avg - pre_covid_avg

# Identify the countries with the largest decreases in happiness scores
top_decreasing_countries = happiness_change.nsmallest(10) 

# Plotting the bar chart
plt.figure(figsize=(10, 6))
top_decreasing_countries.plot(kind='bar', color='red')
plt.title('Top 10 Countries with the Largest Decreases in Happiness Scores Post-COVID')
plt.xlabel('Country')
plt.ylabel('Happiness Score Change')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Load the COVID-19 data
covid_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv')

# Drop rows with missing values in 'location' or 'total_cases' columns
covid_data = covid_data.dropna(subset=['location', 'total_cases'])

# Calculate the standard deviation of total cases for each country
std_by_country = covid_data.groupby('location')['total_cases'].std().reset_index()
std_by_country.columns = ['Country', 'Std_Total_Cases']

# Sort countries based on standard deviation
most_stable_countries = std_by_country.sort_values(by='Std_Total_Cases').head(10)  # Adjust the head count as needed

# Print the most stable countries
print("Top 10 Most Stable Countries based on Total COVID-19 Cases:")
print(most_stable_countries)
# Out:
# Top 10 Most Stable Countries based on Total COVID-19 Cases:
#                Country  Std_Total_Cases
# 173           Pitcairn         0.000000
# 236            Vatican         5.753456
# 219            Tokelau        36.126207
# 158               Niue       404.584162
# 183       Saint Helena       528.002332
# 145         Montserrat       656.016077
# 72    Falkland Islands       922.000921
# 113           Kiribati      1060.014838
# 225             Tuvalu      1229.480884
# 239  Wallis and Futuna      1566.562290

# %%
# Load the COVID-19 data
covid_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv')

# Drop rows with missing values in 'location' or 'total_cases' columns
covid_data = covid_data.dropna(subset=['location', 'total_cases'])

# Calculate the standard deviation of total cases for each country
std_by_country = covid_data.groupby('location')['total_cases'].std().reset_index()
std_by_country.columns = ['Country', 'Std_Total_Cases']

# Sort countries based on standard deviation
most_stable_countries = std_by_country.sort_values(by='Std_Total_Cases').head(10)  # Adjust the head count as needed

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.barh(most_stable_countries['Country'], most_stable_countries['Std_Total_Cases'], color='skyblue')
plt.xlabel('Standard Deviation of Total COVID-19 Cases')
plt.ylabel('Country')
plt.title('Top 10 Most Stable Countries based on Total COVID-19 Cases')
plt.gca().invert_yaxis()  # Invert y-axis to show countries with lowest standard deviation at the top
plt.tight_layout()
plt.show()

# %%
print(merged_data)
# Out:
#                 Country       Year  Index   Rank
# 0           Afghanistan 2013-01-01  4.040  143.0
# 1             Singapore 2013-01-01  6.546   30.0
# 2               Comoros 2013-01-01  3.851  149.0
# 3          Sierra Leone 2013-01-01  4.318  127.0
# 4                 Congo 2013-01-01    NaN    NaN
# ...                 ...        ...    ...    ...
# 1665  Congo Brazzaville 2023-01-01  5.267   86.0
# 1666             Rwanda 2023-01-01    NaN    NaN
# 1667     Congo Kinshasa 2023-01-01  3.207  133.0
# 1668            Comoros 2023-01-01  3.545  130.0
# 1669           Zimbabwe 2023-01-01  3.204  134.0
#
# [1670 rows x 4 columns]

# %%
covid_data.head
# Out:
# <bound method NDFrame.head of        iso_code continent     location        date  total_cases  new_cases  \
# 56          AFG      Asia  Afghanistan  2020-03-01          1.0        1.0
# 57          AFG      Asia  Afghanistan  2020-03-02          1.0        0.0
# 58          AFG      Asia  Afghanistan  2020-03-03          1.0        0.0
# 59          AFG      Asia  Afghanistan  2020-03-04          1.0        0.0
# 60          AFG      Asia  Afghanistan  2020-03-05          1.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 401077      ZWE    Africa     Zimbabwe  2024-05-08     266362.0        0.0
# 401078      ZWE    Africa     Zimbabwe  2024-05-09     266362.0        0.0
# 401079      ZWE    Africa     Zimbabwe  2024-05-10     266362.0        0.0
# 401080      ZWE    Africa     Zimbabwe  2024-05-11     266362.0        0.0
# 401081      ZWE    Africa     Zimbabwe  2024-05-12     266362.0        0.0
#
# ...

# %%
happiness_data.head
# Out:
# <bound method NDFrame.head of                 Country  Year  Index   Rank
# 0           Afghanistan  2013  4.040  143.0
# 1             Singapore  2013  6.546   30.0
# 2               Comoros  2013  3.851  149.0
# 3          Sierra Leone  2013  4.318  127.0
# 4                 Congo  2013    NaN    NaN
# ...                 ...   ...    ...    ...
# 1665  Congo Brazzaville  2023  5.267   86.0
# 1666             Rwanda  2023    NaN    NaN
# 1667     Congo Kinshasa  2023  3.207  133.0
# 1668            Comoros  2023  3.545  130.0
# 1669           Zimbabwe  2023  3.204  134.0
#
# [1670 rows x 4 columns]>

# %%
import pandas as pd

# Load datasets
covid_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv')
happiness_data = pd.read_csv('C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/WorldHappinessIndex2013-2023.csv')

# Convert date columns to datetime
covid_data['date'] = pd.to_datetime(covid_data['date'])
happiness_data['Year'] = happiness_data['Year'].astype(int)

# Extract year from the COVID-19 data
covid_data['year'] = covid_data['date'].dt.year

# Merge datasets on country and year
merged_data = pd.merge(covid_data, happiness_data, left_on=['location', 'year'], right_on=['Country', 'Year'], how='inner')

# Display the first few rows of the merged dataset
print(merged_data.head())
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-01-05          NaN        0.0
# 1      AFG      Asia  Afghanistan 2020-01-06          NaN        0.0
# 2      AFG      Asia  Afghanistan 2020-01-07          NaN        0.0
# 3      AFG      Asia  Afghanistan 2020-01-08          NaN        0.0
# 4      AFG      Asia  Afghanistan 2020-01-09          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    population  excess_mortality_cumulative_absolute  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Summary statistics
print(merged_data.describe())

# Distribution of happiness scores
plt.figure(figsize=(10, 6))
sns.histplot(merged_data['Index'], bins=30, kde=True)
plt.title('Distribution of Happiness Scores')
plt.xlabel('Happiness Index')
plt.ylabel('Frequency')
plt.show()
# Out:
#                                 date   total_cases     new_cases  \
# count                         232994  2.184660e+05  2.294370e+05
# mean   2022-01-01 19:11:56.588409856  2.428025e+06  3.280921e+03
# min              2020-01-01 00:00:00  1.000000e+00  0.000000e+00
# 25%              2021-01-03 00:00:00  2.656700e+04  0.000000e+00
# 50%              2022-01-02 00:00:00  2.149550e+05  0.000000e+00
# 75%              2023-01-01 00:00:00  1.106065e+06  0.000000e+00
# max              2023-12-31 00:00:00  1.034368e+08  4.047548e+07
# std                              NaN  8.781837e+06  1.118345e+05
#
#        new_cases_smoothed  total_deaths     new_deaths  new_deaths_smoothed  \
# count        2.286470e+05  2.127400e+05  229667.000000        228877.000000
# mean         3.291288e+03  2.993090e+04      30.013237            30.102313
# min          0.000000e+00  1.000000e+00       0.000000             0.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data structure for merged_data
merged_data = pd.DataFrame({
    'total_cases': [100, 200, 300, 400],
    'total_deaths': [5, 10, 15, 20],
    'Index': [7.5, 7.2, 7.8, 7.9]
})

# Set the overall figure size for multiple plots
plt.figure(figsize=(14, 12))
sns.set(style="whitegrid")  # Set white background for the plots

# Define a brighter happy color palette
happy_palette = sns.color_palette(["#FF6F61", "#FFC300", "#34E7E4", "#FF9F1C", "#6A0572", "#2A363B"])

# Plotting the regression results for Total COVID-19 Cases
plt.subplot(2, 1, 1)  # 2 rows, 1 column, first subplot
sns.regplot(x='total_cases', y='Index', data=merged_data, scatter_kws={'s': 70, 'color': happy_palette[0]}, line_kws={'color': happy_palette[1]})
plt.title('Regression of Happiness Index on Total COVID-19 Cases', fontsize=18, weight='bold', color=happy_palette[2])
plt.xlabel('Total COVID-19 Cases', fontsize=16, color=happy_palette[3])
plt.ylabel('Happiness Index', fontsize=16, color=happy_palette[3])

# Customizing grid lines to be less prominent
ax = plt.gca()
ax.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.6)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Plotting the regression results for Total COVID-19 Deaths
plt.subplot(2, 1, 2)  # 2 rows, 1 column, second subplot
sns.regplot(x='total_deaths', y='Index', data=merged_data, scatter_kws={'s': 70, 'color': happy_palette[3]}, line_kws={'color': happy_palette[4]})
plt.title('Regression of Happiness Index on Total COVID-19 Deaths', fontsize=18, weight='bold', color=happy_palette[2])
plt.xlabel('Total COVID-19 Deaths', fontsize=16, color=happy_palette[3])
plt.ylabel('Happiness Index', fontsize=16, color=happy_palette[3])

# Customizing grid lines to be less prominent
ax = plt.gca()
ax.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.6)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.tight_layout()
plt.show()

# %%
# Load the datasets
covid_data_path = 'C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv'
happiness_data_path = 'C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/WorldHappinessIndex2013-2023.csv'

covid_data = pd.read_csv(covid_data_path)
happiness_data = pd.read_csv(happiness_data_path)

# Merge the datasets on a common key, for example, 'location' and 'Year'
# Ensure 'location' in covid_data and 'Country' in happiness_data are the same
merged_data = pd.merge(covid_data, happiness_data, how='inner', left_on='location', right_on='Country')

# Calculate the correlation matrix
correlation_matrix = merged_data[['total_cases', 'total_deaths', 'Index']].corr()

# Visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=.5)
plt.title('Correlation Matrix of COVID-19 Data and Happiness Index')
plt.show()

# Print the correlation matrix for review
print(correlation_matrix)
# Out:
#               total_cases  total_deaths     Index
# total_cases      1.000000      0.790468  0.164903
# total_deaths     0.790468      1.000000  0.158718
# Index            0.164903      0.158718  1.000000

# %% [markdown]
# ### Conclusion
#
# - The analysis indicates a potential correlation between COVID-19 metrics and happiness scores.
# - Regression results suggest that higher COVID-19 cases and deaths might be associated with lower happiness scores.
# - The impact varies across different regions and countries.
#
# ### Limitations
# - The analysis assumes the reported data is accurate and consistent.
# - Other factors influencing happiness during the pandemic are not accounted for.
#
# ### Future Work
# - Include more variables such as economic indicators, healthcare quality, and government response indices.
# - Perform a more granular analysis at the regional or city level.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the COVID-19 dataset
covid_data_path = 'C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv'
covid_data = pd.read_csv(covid_data_path)

# Convert 'date' to datetime format for better handling
covid_data['date'] = pd.to_datetime(covid_data['date'])

# Extract the year from the date
covid_data['year'] = covid_data['date'].dt.year

# Group by year and sum up the new cases globally
global_cases_data = covid_data.groupby('year').agg({'new_cases': 'sum'}).reset_index()

# Create a plot for New Cases over years worldwide with enhanced aesthetics
plt.figure(figsize=(16, 10))


# Plotting New Cases with a vibrant color palette
sns.lineplot(data=global_cases_data, x='year', y='new_cases', label='New Cases', color='black', marker='o', linewidth=3)

# Adding titles, labels, and annotations
plt.title('Global Trends in New COVID-19 Cases Over the Years', fontsize=18, fontweight='bold', color='black')
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of New Cases', fontsize=16)
plt.xticks(global_cases_data['year'], rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper left', fontsize=12)

# Adding annotations for significant events (example)
events = {2020: 'Pandemic Outbreak', 2021: 'Vaccine Rollouts', 2022: 'Ongoing Monitoring'}
for year, event in events.items():
    plt.annotate(event, (year, global_cases_data[global_cases_data['year'] == year]['new_cases'].values[0]),
                 textcoords="offset points", xytext=(0, 10), ha='center', fontsize=10, color='black', backgroundcolor='white')

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the COVID-19 dataset
covid_data_path = 'C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv'
covid_data = pd.read_csv(covid_data_path)

# Convert 'date' to datetime format for better handling
covid_data['date'] = pd.to_datetime(covid_data['date'])

# Extract the year from the date
covid_data['year'] = covid_data['date'].dt.year

# Group by year and sum up the total cases globally
global_cases_data = covid_data.groupby('year').agg({'total_cases': 'sum'}).reset_index()

# Define significant events and their corresponding years for annotation
events = {
    2020: 'Pandemic Outbreak',
    2020: 'First Lockdowns Worldwide',
    2021: 'Vaccine Rollout Begins',
    2021: 'Delta Variant Emergence',
    2022: 'Omicron Variant Emergence',
    2023: 'Endemic Transition Discussions'
}

# Create a plot for Total Cases over years worldwide with a COVID-19 theme
plt.figure(figsize=(14, 8))
sns.set_theme(style="darkgrid")

# Plotting Total Cases
sns.lineplot(data=global_cases_data, x='year', y='total_cases', color='red', marker='o', linewidth=2.5)

# Adding titles and labels
plt.title('Global Trends in Total COVID-19 Cases Over the Years', fontsize=18, fontweight='bold', color='darkred')
plt.xlabel('Year', fontsize=16)
plt.ylabel('Cumulative Total Cases', fontsize=16)
plt.xticks(global_cases_data['year'], rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Adding annotations for significant events
for year, event in events.items():
    # Find the corresponding value for the year to annotate
    cases_value = global_cases_data[global_cases_data['year'] == year]['total_cases'].values[0]
    plt.annotate(event, (year, cases_value), textcoords="offset points", xytext=(0, 10), ha='center',
                 fontsize=10, color='black', backgroundcolor='yellow')

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the COVID-19 dataset
covid_data_path = 'C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv'
covid_data = pd.read_csv(covid_data_path)

# Convert 'date' to datetime format for better handling
covid_data['date'] = pd.to_datetime(covid_data['date'])

# Extract the year from the date
covid_data['year'] = covid_data['date'].dt.year

# Group by year and sum up the new cases globally
global_cases_data = covid_data.groupby('year').agg({'new_cases': 'sum'}).reset_index()

# Define significant events and their corresponding years for annotation
events = {
    2020: 'Pandemic Outbreak',
    2021: 'Vaccine Rollout Begins',
    2021: 'Delta Variant Emergence',  # Note: Event already defined, replaced with this example
    2022: 'Omicron Variant Emergence',
    2023: 'Endemic Transition Discussions'
}

# Create a plot for New Cases over years worldwide
plt.figure(figsize=(14, 8))
sns.set_theme(style="darkgrid")

# Plotting New Cases
sns.lineplot(data=global_cases_data, x='year', y='new_cases', color='red', marker='o', linewidth=2.5)

# Adding titles and labels
plt.title('Global Trends in New COVID-19 Cases Over the Years', fontsize=18, fontweight='bold', color='darkred')
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of New Cases', fontsize=16)
plt.xticks(global_cases_data['year'], rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Adding annotations for significant events
for year, event in events.items():
    # Find the corresponding value for the year to annotate
    cases_value = global_cases_data[global_cases_data['year'] == year]['new_cases'].values[0]
    plt.annotate(event, (year, cases_value), textcoords="offset points", xytext=(0, 10), ha='center',
                 fontsize=10, color='black', backgroundcolor='white')

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the COVID-19 dataset
covid_data_path = 'C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/owid-covid-data (1).csv'
covid_data = pd.read_csv(covid_data_path)

# Convert 'date' to datetime format for better handling
covid_data['date'] = pd.to_datetime(covid_data['date'])

# Extract the year from the date
covid_data['year'] = covid_data['date'].dt.year

# Group by year and sum up the new deaths globally
global_deaths_data = covid_data.groupby('year').agg({'new_deaths': 'sum'}).reset_index()

# Define significant events and their corresponding years for annotation
events = {
    2020: 'Pandemic Outbreak',
    2021: 'Vaccine Rollout Begins',
    2022: 'Omicron Variant Emergence',
    2023: 'Endemic Transition Discussions'
}

# Create a plot for New Deaths over years worldwide with a COVID-19 theme
plt.figure(figsize=(14, 8))
sns.set_theme(style="darkgrid")

# Plotting New Deaths
sns.lineplot(data=global_deaths_data, x='year', y='new_deaths', color='red', marker='o', linewidth=2.5)

# Adding titles and labels
plt.title('Global Trends in New COVID-19 Deaths Over the Years', fontsize=18, fontweight='bold', color='darkred')
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of New Deaths', fontsize=16)
plt.xticks(global_deaths_data['year'], rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Adding annotations for significant events
for year, event in events.items():
    # Find the corresponding value for the year to annotate
    deaths_value = global_deaths_data[global_deaths_data['year'] == year]['new_deaths'].values[0]
    plt.annotate(event, (year, deaths_value), textcoords="offset points", xytext=(0, 10), ha='center',
                 fontsize=10, color='white', backgroundcolor='black')

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the World Happiness Index dataset
happiness_data_path = 'C:/Users/georg/git repositories/project 1 group 16/project_1group_16_/WorldHappinessIndex2013-2023.csv'
happiness_data = pd.read_csv(happiness_data_path)

# Display the first few rows of the dataset to understand its structure
print(happiness_data.head())

# Group by year and calculate the average happiness score
average_happiness = happiness_data.groupby('Year').agg({'Index': 'mean'}).reset_index()

# Define significant events and their corresponding years for annotation
events = {
    2015: 'First Data Published',
    2016: 'Increasing Awareness',
    2017: 'Global Collaboration Initiatives',
    2018: 'Mental Health Awareness',
    2019: 'Growing Research Focus',
    2020: 'COVID-19 Pandemic Begins',
    2021: 'Pandemic Response Initiatives',
    2022: 'End of COVID-19 Emergency in Many Countries',
    2023: 'Post-Pandemic Adjustments'
}

# Create a plot for Happiness Index scores over the years
plt.figure(figsize=(14, 8))
sns.set_theme(style="darkgrid")

# Plotting the Happiness Index
sns.lineplot(data=average_happiness, x='Year', y='Index', marker='o', color='blue', linewidth=2.5)

# Adding titles and labels
plt.title('Global Happiness Index Over the Years', fontsize=18, fontweight='bold', color='green')
plt.xlabel('Year', fontsize=16)
plt.ylabel('Average Happiness Score', fontsize=16)
plt.xticks(average_happiness['Year'], rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Adding annotations for significant events
for year, event in events.items():
    # Find the corresponding value for the year to annotate
    index_value = average_happiness[average_happiness['Year'] == year]['Index'].values[0]
    plt.annotate(event, (year, index_value), textcoords="offset points", xytext=(0, 10), ha='center',
                 fontsize=10, color='yellow', backgroundcolor='green')

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#         Country  Year  Index   Rank
# 0   Afghanistan  2013  4.040  143.0
# 1     Singapore  2013  6.546   30.0
# 2       Comoros  2013  3.851  149.0
# 3  Sierra Leone  2013  4.318  127.0
# 4         Congo  2013    NaN    NaN
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\georg\.conda\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(14, 7))
plt.plot(covid_data['total_cases'], label='Total Cases')
plt.plot(covid_data['total_deaths'], label='Total Deaths')
plt.title('COVID-19 Total Cases and Deaths Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.show()
